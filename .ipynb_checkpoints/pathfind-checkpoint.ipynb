# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
ret, thresh = cv.threshold(cv.cvtColor(cv.imread('road.jpeg'), cv.COLOR_BGR2GRAY), 200, 255, 0)
white = np.ones(road.shape, dtype=np.uint8)*255

# %%
plt.imshow(thresh)

# %%
contours, h= cv.findContours(thresh, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# %%
cv.drawContours(white, contours, -1, (0,255,0), 3)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(white)

# %%
cv.imwrite('c.jpeg', white)
# Out:
# True
